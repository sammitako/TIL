# %% [markdown]
# # Data Analysis - MoviesLes dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

movies = pd.read_csv('data/movies.csv')
ratings = pd.read_csv('data/ratings.csv')

# %% [markdown]
# ## 데이터 파악

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
movies.shape
# Out:
# (9742, 3)

# %%
ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# ### 중복값 제거

# %%
print(ratings.drop_duplicates('userId', keep='first')) # 610
print(movies.drop_duplicates('movieId', keep='first')) # 9742
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 232         2      318     3.0  1445714835
# 261         3       31     0.5  1306463578
# 300         4       21     3.0   986935199
# 516         5        1     4.0   847434962
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [610 rows x 4 columns]
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# ### 같은 컬럼을 기준으로 데이터 병합

# %%
data = pd.merge(movies, ratings)
display(data)
data.shape
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy       7     4.5
# 3       Adventure|Animation|Children|Comedy|Fantasy      15     2.5
# 4       Adventure|Animation|Children|Comedy|Fantasy      17     4.5
# ...                                             ...     ...     ...
# 100831              Action|Animation|Comedy|Fantasy     184     4.0
# 100832                     Animation|Comedy|Fantasy     184     3.5
# 100833                                        Drama     184     3.5
# 100834                             Action|Animation     184     3.5
# 100835                                       Comedy     331     4.0
#
#          timestamp
# 0        964982703
# 1        847434962
# 2       1106635946
# 3       1510577970
# 4       1305696483
# ...            ...
# 100831  1537109082
# 100832  1537109545
# 100833  1537109805
# 100834  1537110021
# 100835  1537157606
#
# [100836 rows x 6 columns]
# (100836, 6)

# %% [markdown]
# ## [문제 1] 사용자가 평가한 모든 영화의 전체 평균 평점

# %%
movies_mean = ratings['rating'].mean()
print(movies_mean)
# Out:
# 3.501556983616962

# %% [markdown]
# ## [문제 2] 각 사용자별 평균 평점

# %%
user_rating_mean = ratings['rating'].groupby(ratings['userId']).mean()
display(user_rating_mean)
# Out:
# userId
# 1      4.366379
# 2      3.948276
# 3      2.435897
# 4      3.555556
# 5      3.636364
#          ...
# 606    3.657399
# 607    3.786096
# 608    3.134176
# 609    3.270270
# 610    3.688556
# Name: rating, Length: 610, dtype: float64

# %% [markdown]
# ## [문제 3] 각 영화별 평균 평점

# %% [markdown]
# ### ❌ ratings이라는 DataFrame에서만 구했을 경우, Length: 9724
# * ratings: 평점이 있는 영화만 존재
# * movies: 모든 영화가 존재
# * data: 공통 컬럼인 `movieId`를 기준으로 ratings, movies를 합침, 결국 평점이 없는 영화는 자동 배제됨
# * 따라서 movies의 데이터는 총 9742개인 반면, 아래의 코드를 실행 시 데이터의 갯수는 9724개로 줄어들었음

# %%
movie_rating_mean = ratings['rating'].groupby(ratings['movieId']).mean()
movie_rating_mean # Length: 9724
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %% [markdown]
# ### ⭕️ 평점이 매겨지지 않은 영화도 포함하여 다시 계산할 경우, Length: 9742
# * moives를 기준으로 movies와 movie_rating_mean을 다시 병합
# * `left_on='movieId`': movies의 `moiveId`라는 컬럼을 기준으로 병합
# * `right_index=True`: movie_rating_mean의 인덱스(`movieId`)를 기준으로 병합
# * `how='left'`: 왼쪽에 존재한 movies에, 오른쪽에 위치한 movie_rating_mean을 갖다붙임

# %%
df = pd.merge(movies, movie_rating_mean, left_on='movieId', right_index=True, how='left')
movie_rating_mean = df[['movieId', 'title', 'rating']]
display(movie_rating_mean) # Length: 9742

# 평점이 매겨지지 않은 영화 확인 - NaN
movie_rating_mean.loc[movie_rating_mean['rating'].isna(), :] # 18개 = 9742 - 9724
# Out:
#       movieId                                      title    rating
# 0           1                           Toy Story (1995)  3.920930
# 1           2                             Jumanji (1995)  3.431818
# 2           3                    Grumpier Old Men (1995)  3.259615
# 3           4                   Waiting to Exhale (1995)  2.357143
# 4           5         Father of the Bride Part II (1995)  3.071429
# ...       ...                                        ...       ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)  4.000000
# 9738   193583               No Game No Life: Zero (2017)  3.500000
# 9739   193585                               Flint (2017)  3.500000
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)  3.500000
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)  4.000000
#
# [9742 rows x 3 columns]
#       movieId                                         title  rating
# 816      1076                         Innocents, The (1961)     NaN
# 2211     2939                                Niagara (1953)     NaN
# 2499     3338                        For All Mankind (1989)     NaN
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)     NaN
# 3118     4194                I Know Where I'm Going! (1945)     NaN
# 4037     5721                            Chosen, The (1981)     NaN
# 4506     6668   Road Home, The (Wo de fu qin mu qin) (1999)     NaN
# 4598     6849                                Scrooge (1970)     NaN
# 4704     7020                                  Proof (1991)     NaN
# 5020     7792                     Parallax View, The (1974)     NaN
# 5293     8765                      This Gun for Hire (1942)     NaN
# 5421    25855                  Roaring Twenties, The (1939)     NaN
# 5452    26085                   Mutiny on the Bounty (1962)     NaN
# 5749    30892            In the Realms of the Unreal (2004)     NaN
# 5824    32160                      Twentieth Century (1934)     NaN
# 5837    32371                     Call Northside 777 (1948)     NaN
# 5957    34482                  Browning Version, The (1951)     NaN
# 7565    85565                            Chalet Girl (2011)     NaN

# %% [markdown]
# ## [문제 4] 평균 평점이 가장 높은 영화의 제목
# **(단, 동률이 있을 경우 모두 출력하되, title을 기준으로 오름차순 정렬)**

# %%
movie_max = movie_rating_mean.loc[movie_rating_mean['rating'].max() == movie_rating_mean['rating'], :]
result = movie_max.sort_values(by='title', ascending=True)
display(result)
# Out:
#       movieId                             title  rating
# 5690    27751               'Salem's Lot (2004)     5.0
# 7332    77846               12 Angry Men (1997)     5.0
# 9046   141816                  12 Chairs (1976)     5.0
# 3893     5468  20 Million Miles to Earth (1957)     5.0
# 5639    27373                        61* (2001)     5.0
# ...       ...                               ...     ...
# 9711   187717  Won't You Be My Neighbor? (2018)     5.0
# 8355   108795               Wonder Woman (2009)     5.0
# 9289   158398             World of Glory (1991)     5.0
# 9560   173351       Wow! A Talking Fish! (1983)     5.0
# 7521    84273  Zeitgeist: Moving Forward (2011)     5.0
#
# [296 rows x 3 columns]

# %% [markdown]
# ## [문제 5] Comedy 영화 중 가장 평점이 낮은 영화의 제목
# **(단, 동률이 있을 경우 모두 출력하되, title을 기준으로 오름차순 정렬)**

# %%
movie_rating_mean = df[['movieId', 'title', 'rating', 'genres']]

comedy_movie = movie_rating_mean.loc[movie_rating_mean['genres'].str.contains('Comedy'), :]
comedy_min = comedy_movie.loc[comedy_movie['rating'].min() == comedy_movie['rating'], :]
result = comedy_min.sort_values(by='title', ascending=True)
display(result)
# Out:
#       movieId                                              title  rating  \
# 8893   134528                                       Aloha (2015)     0.5
# 5777    31422                           Are We There Yet? (2005)     0.5
# 7762    91414                            Arthur Christmas (2011)     0.5
# 9419   165645                                 Bad Santa 2 (2016)     0.5
# 4439     6557                             Born to Be Wild (1995)     0.5
# 5409    25782  Boudu Saved From Drowning (Boudu sauvé des eau...     0.5
# 6554    54934                       Brothers Solomon, The (2007)     0.5
# 5453    26095         Carabineers, The (Carabiniers, Les) (1963)     0.5
# 6545    54768                              Daddy Day Camp (2007)     0.5
# 4881     7312                            Follow Me, Boys! (1966)     0.5
# 7553    85334                       Hard Ticket to Hawaii (1987)     0.5
# 8417   110773                          Haunted House 2, A (2014)     0.5
# 5662    27595                 Jesus Christ Vampire Hunter (2001)     0.5
# 8984   138798                 Joe Dirt 2: Beautiful Loser (2015)     0.5
# 7820    92681            Journey 2: The Mysterious Island (2012)     0.5
# 6160    44243                      Leprechaun 4: In Space (1997)     0.5
# 8248   104644  Maria Bamford: The Special Special Special! (2...     0.5
# 7201    72696                                    Old Dogs (2009)     0.5
# 9056   141994                            Saving Christmas (2014)     0.5
# 5258     8632                              Secret Society (2002)     0.5
# 9590   175475                             The Emoji Movie (2017)     0.5
# 8908   135216               The Star Wars Holiday Special (1978)     0.5
# 8676   122246                               Tooth Fairy 2 (2012)     0.5
# 5795    31692                                  Uncle Nino (2003)     0.5
# 6784    60363                           Zombie Strippers! (2008)     0.5
#
#                                    genres
# 8893                 Comedy|Drama|Romance
# 5777                      Children|Comedy
# 7762      Animation|Children|Comedy|Drama
# 9419                               Comedy
# 4439      Adventure|Children|Comedy|Drama
# 5409                               Comedy
# 6554                               Comedy
# 5453                     Comedy|Drama|War
# 6545                      Children|Comedy
# 4881                         Comedy|Drama
# 7553                        Action|Comedy
# 8417                        Comedy|Horror
# 5662         Action|Comedy|Horror|Musical
# 8984                               Comedy
# 7820  Action|Adventure|Comedy|Sci-Fi|IMAX
# 6160         Comedy|Fantasy|Horror|Sci-Fi
# 8248                               Comedy
# 7201                               Comedy
# 9056                      Children|Comedy
# 5258                               Comedy
# 9590            Animation|Children|Comedy
# 8908     Adventure|Children|Comedy|Sci-Fi
# 8676                      Children|Comedy
# 5795                               Comedy
# 6784                        Comedy|Horror

# %% [markdown]
# ## [문제 6] 2015년도에 평가된 모든 Romance 영화의 평균 평점

# %% [markdown]
# ### Romance 영화의 평균 평점

# %%
romance_movie = movie_rating_mean.loc[movie_rating_mean['genres'].str.contains('Romance'), :]
display(romance_movie)
romance_movie_tm = pd.merge(romance_movie, ratings['timestamp'], left_on='movieId', right_index=True, how='left')
display(romance_movie_tm)
# Out:
#       movieId                                title    rating  \
# 2           3              Grumpier Old Men (1995)  3.259615
# 3           4             Waiting to Exhale (1995)  2.357143
# 6           7                       Sabrina (1995)  3.185185
# 10         11       American President, The (1995)  3.671429
# 14         15              Cutthroat Island (1995)  3.000000
# ...       ...                                  ...       ...
# 9639   179511                 Emerald Green (2016)  4.000000
# 9660   181315                Phantom Thread (2017)  3.500000
# 9691   184349                   Elsa & Fred (2005)  3.500000
# 9715   188751  Mamma Mia: Here We Go Again! (2018)  4.500000
# 9725   190207                          Tilt (2011)  1.500000
#
#                                genres
# 2                      Comedy|Romance
# 3                Comedy|Drama|Romance
# 6                      Comedy|Romance
# 10               Comedy|Drama|Romance
# 14           Action|Adventure|Romance
# ...                               ...
# 9639  Adventure|Drama|Fantasy|Romance
# 9660                    Drama|Romance
# 9691             Comedy|Drama|Romance
# 9715                   Comedy|Romance
# 9725                    Drama|Romance
#
# [1596 rows x 4 columns]
#       movieId                                title    rating  \
# 2           3              Grumpier Old Men (1995)  3.259615
# 3           4             Waiting to Exhale (1995)  2.357143
# 6           7                       Sabrina (1995)  3.185185
# 10         11       American President, The (1995)  3.671429
# 14         15              Cutthroat Island (1995)  3.000000
# ...       ...                                  ...       ...
# 9639   179511                 Emerald Green (2016)  4.000000
# 9660   181315                Phantom Thread (2017)  3.500000
# 9691   184349                   Elsa & Fred (2005)  3.500000
# 9715   188751  Mamma Mia: Here We Go Again! (2018)  4.500000
# 9725   190207                          Tilt (2011)  1.500000
#
#                                genres    timestamp
# 2                      Comedy|Romance  964983815.0
# 3                Comedy|Drama|Romance  964982931.0
# 6                      Comedy|Romance  964982176.0
# 10               Comedy|Drama|Romance  964981208.0
# 14           Action|Adventure|Romance  964981680.0
# ...                               ...          ...
# 9639  Adventure|Drama|Fantasy|Romance          NaN
# 9660                    Drama|Romance          NaN
# 9691             Comedy|Drama|Romance          NaN
# 9715                   Comedy|Romance          NaN
# 9725                    Drama|Romance          NaN
#
# [1596 rows x 5 columns]

# %% [markdown]
# ### timestamp 다루기

# %%
import time
start = time.mktime(time.strptime("2015-01-01 00:00:00","%Y-%m-%d %H:%M:%S"))
end = time.mktime(time.strptime("2016-01-01 00:00:00","%Y-%m-%d %H:%M:%S"))

result = romance_movie_tm.loc[(romance_movie_tm["timestamp"] >= start) & (romance_movie_tm["timestamp"] < end),"rating"]
display(result)
# Out:
# 198     3.892857
# 202     3.477778
# 203     3.340909
# 205     3.000000
# 213     3.722222
# 216     3.453488
# 222     2.600000
# 2584    3.000000
# 2637    3.400000
# 2690    3.750000
# 2708    3.264706
# 5402    3.000000
# 5405    4.000000
# 5406    4.500000
# 5411    3.500000
# 6005    3.534091
# 6012    2.000000
# 6140    3.000000
# 6165    4.117647
# 6186    4.250000
# 6204    3.250000
# 6210    2.590909
# 6282    3.500000
# 6285    2.500000
# 6362    3.000000
# 6574    3.000000
# 6652    3.000000
# 6809    3.000000
# 6968    2.818182
# 7087    3.666667
# 7094    3.500000
# 7351    2.833333
# 7416    3.796296
# 7417    3.500000
# 7420    4.000000
# 7421    3.833333
# 7632    2.750000
# Name: rating, dtype: float64

# %% [markdown]
# ### 2015년도에 평가된 모든 Romance 영화의 평균 평점

# %%
answer = result.mean()
print(answer)
# Out:
# 3.3335788917526257
